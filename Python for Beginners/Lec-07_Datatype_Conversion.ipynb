# %% [markdown]
# # Datatype Conversion

# %%
no_int = 3 
type(no_int)
# Out:
# int

# %%
no_str = '7' 
type(no_str)
# Out:
# str

# %%
no_str_conv = int(no_str)
type(no_str_conv)
# Out:
# int

# %%
no_sum = no_int + no_str_conv
print(no_sum)
# Out:
# 10

# %%
type(no_sum)
# Out:
# int

# %%
list_type = [1,2,3]
type(list_type)
# Out:
# list

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type = [1,2,3,3,3,4,4,5,5,6]
set(list_type)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
type(set(list_type))
# Out:
# set

# %%
dict_type = {'Name':'Alex','Age':28,'Hair':'N/A'}
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('Name', 'Alex'), ('Age', 28), ('Hair', 'N/A')])

# %%
dict_type.values()
# Out:
# dict_values(['Alex', 28, 'N/A'])

# %%
dict_type.keys()
# Out:
# dict_keys(['Name', 'Age', 'Hair'])

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_str = 'I like to party'
list(long_str)
# Out:
# ['I', ' ', 'l', 'i', 'k', 'e', ' ', 't', 'o', ' ', 'p', 'a', 'r', 't', 'y']

# %%
set(long_str)
# Out:
# {' ', 'I', 'a', 'e', 'i', 'k', 'l', 'o', 'p', 'r', 't', 'y'}
